# %% [markdown]
# This is a startbook for binary-Class , please see binary book for that starter pack
#
# This notebook is a "starter" file that just concats and labels all of our datasets. Team members will clone this notebook and build off of it to ensure uniformity across ML models. make sure all the csv's that are being imported to this are in your working directory!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

# %%
# Create a custom function for data transformation
# May as well import all of these features into the initial dataframe, you can cut it down..
# ..when you do the X,y train/test split
features = ['datetime',
          'latitude',
          'longitude',
          'absoluteAltitude', 
          'magneticHeading',
          'trueHeading', 
          'groundSpeed', 
          'trueAirspeed',
          'pitch', 
          'roll',
          'yaw',
          'angleOfAttack',
          'flightPathAngle',
          'verticalFlightPathAngle',
          'horizontalFlightPathAngle',
          'rollAcceleration',
          'pitchAcceleration',
          'yawAcceleration',
          'e1N1ng',
          'e2N1ng',
          'e1N2nf',
          'e2N2nf',
          'mainRotorRpm',
          'tailRotorRpm',
          'mainRotorTorque',
          'e1Itt',
          'e2Itt',
          'mainRotorInducedInflow',
          'flightDirectorPitch',
          'flightDirectorRoll',
          'climbOrDescentRate', 
          'hasWeightOnWheels',
          'turnRate to degPerSec',
          'cyclicPositionPitch',
          'cyclicPositionRoll',
          'collectivePosition',
          'antiTorquePedalPosition',
          'throttlePosition',
          'e1Torque',
          'e2Torque',
]


def df_transformation(df):
    df_temp = df[features]
    df_temp['datetime'] = df_temp.datetime.dt.strftime('%Y-%m-%d %H:%M:%S').astype('datetime64[ns]')

    output = df_temp.groupby(by=["datetime"], dropna=False).mean().reset_index()
    
    return output

# %%
# reading files from 9/19 dataset
df1 = pd.read_csv('SimData_2022.09.19_16.00.36.csv.roar.csv',
                parse_dates = {'datetime': ['date', 'time']},
                low_memory=False)
df1 = df_transformation(df1)


df2 = pd.read_csv('SimData_2022.09.19_16.38.20.csv.roar.csv',
                parse_dates = {'datetime': ['date', 'time']},
                low_memory=False)
df2 = df_transformation(df2)


df3 = pd.read_csv('SimData_2022.09.19_17.51.37.csv.roar.csv',
                parse_dates = {'datetime': ['date', 'time']},
                low_memory=False)
df3 = df_transformation(df3)



# reading files from 9/20 dataset
first_file = pd.read_csv('SimData_2022.09.20_16.22.07.csv.roar.csv',
                parse_dates = {'datetime': ['date', 'time']},
                low_memory=False)
first_file = df_transformation(first_file)


second_file = pd.read_csv('SimData_2022.09.20_16.28.31.csv.roar.csv',
                parse_dates = {'datetime': ['date', 'time']},
                low_memory=False)
second_file = df_transformation(second_file)


# reading file from 9/22 dataset
df4 = pd.read_csv('SimData_2022.09.22_17.11.56.csv.roar.csv',
                parse_dates = {'datetime': ['date', 'time']},
                low_memory=False)
df4 = df_transformation(df4)
# Out:
# C:\Users\twolf\AppData\Local\Temp\ipykernel_28128\314500030.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['datetime'] = df_temp.datetime.dt.strftime('%Y-%m-%d %H:%M:%S').astype('datetime64[ns]')
# C:\Users\twolf\AppData\Local\Temp\ipykernel_28128\314500030.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['datetime'] = df_temp.datetime.dt.strftime('%Y-%m-%d %H:%M:%S').astype('datetime64[ns]')
# C:\Users\twolf\AppData\Local\Temp\ipykernel_28128\314500030.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['datetime'] = df_temp.datetime.dt.strftime('%Y-%m-%d %H:%M:%S').astype('datetime64[ns]')
# C:\Users\twolf\AppData\Local\Temp\ipykernel_28128\314500030.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['datetime'] = df_temp.datetime.dt.strftime('%Y-%m-%d %H:%M:%S').astype('datetime64[ns]')
# C:\Users\twolf\AppData\Local\Temp\ipykernel_28128\314500030.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['datetime'] = df_temp.datetime.dt.strftime('%Y-%m-%d %H:%M:%S').astype('datetime64[ns]')
# C:\Users\twolf\AppData\Local\Temp\ipykernel_28128\314500030.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['datetime'] = df_temp.datetime.dt.strftime('%Y-%m-%d %H:%M:%S').astype('datetime64[ns]')

# %%
#Combine files
df = pd.concat([first_file,second_file, df1, df2, df3, df4]).reset_index()

# %%
df
# Out:
#       index            datetime   latitude   longitude  absoluteAltitude  \
# 0         0 2022-09-20 20:22:07  39.449977  -74.584993          0.650000
# 1         1 2022-09-20 20:22:08  39.449982  -74.584989          0.939474
# 2         2 2022-09-20 20:22:09  39.449991  -74.584983          1.602105
# 3         3 2022-09-20 20:22:10  39.450000  -74.584978          2.506389
# 4         4 2022-09-20 20:22:11  39.450010  -74.584973          2.753750
# ...     ...                 ...        ...         ...               ...
# 7215   2082 2022-09-22 21:56:36  20.888637 -156.433109          0.070000
# 7216   2083 2022-09-22 21:56:37  20.888637 -156.433109          0.070000
# 7217   2084 2022-09-22 21:56:38  20.888637 -156.433109          0.070000
# 7218   2085 2022-09-22 21:56:39  20.888637 -156.433109          0.070000
# 7219   2086 2022-09-22 21:56:40  20.888637 -156.433109          0.070000
#
#       magneticHeading  trueHeading  groundSpeed  trueAirspeed     pitch  ...  \
# 0           32.175222    19.886000     1.742333      1.749539  2.787000  ...
# 1           32.293053    20.003579     2.037737      2.065586  3.426684  ...
# 2           32.466921    20.177553     2.229158      2.284727  5.960763  ...
# 3           32.672500    20.383167     2.149028      2.200058  5.446833  ...
# 4           32.770150    20.480700     2.209575      2.210113  4.934150  ...
# ...               ...          ...          ...           ...       ...  ...
# 7215       342.290000   351.771000     0.000000      0.000000 -0.436000  ...
# 7216       342.290000   351.771000     0.000000      0.000000 -0.436000  ...
# 7217       342.290000   351.771000     0.000000      0.000000 -0.436000  ...
# 7218       342.290000   351.771000     0.000000      0.000000 -0.436000  ...
# 7219       342.290000   351.771000     0.000000      0.000000 -0.436000  ...
#
#       climbOrDescentRate  hasWeightOnWheels  turnRate to degPerSec  \
# 0               3.942778                0.0              -0.344556
# 1              13.339816                0.0              -0.249237
# 2              31.786895                0.0              -0.127316
# 3              48.706833                0.0              -0.011861
# 4              30.561375                0.0               0.037625
# ...                  ...                ...                    ...
# 7215            0.000000                1.0               0.000000
# 7216            0.000000                1.0               0.000000
# 7217            0.000000                1.0               0.000000
# 7218            0.000000                1.0               0.000000
# 7219            0.000000                1.0               0.000000
#
#       cyclicPositionPitch  cyclicPositionRoll  collectivePosition  \
# 0               -7.145222           -1.755778           43.350556
# 1                4.024526           -0.637526           43.419368
# 2               -8.350974            0.089816           43.846368
# 3               -4.655806           -0.398667           43.654750
# 4               -5.008675            0.533225           43.526300
# ...                   ...                 ...                 ...
# 7215             5.724000           79.748923            3.633000
# 7216             5.724000           80.041588            3.633000
# 7217             5.723900           80.334720            3.633000
# 7218             5.723920           80.629420            3.633000
# 7219             5.723929           80.855500            3.633000
#
#       antiTorquePedalPosition  throttlePosition   e1Torque   e2Torque
# 0                   -6.749556         53.447444  54.815889  54.815889
# 1                   -6.691947         53.855500  56.059921  56.059921
# 2                   -6.686974         53.765184  56.152684  56.152684
# 3                   -6.678250         53.635083  55.965278  55.965278
# 4                   -5.647800         53.110525  54.661125  54.661125
# ...                       ...               ...        ...        ...
# 7215               -21.672000          0.000000   4.607000   4.607000
# 7216               -21.672000          0.000000   4.607059   4.607059
# 7217               -21.672000          0.000000   4.608000   4.608000
# 7218               -21.672000          0.000000   4.608000   4.608000
# 7219               -21.672000          0.000000   4.608000   4.608000
#
# [7220 rows x 41 columns]

# %% [markdown]
# # Datafrome for Surface Taxi maneuver

# %%
df_s = df.copy()
df_s['surface'] = 0

df_s.loc[(df_s['datetime'].between('2022-09-19 21:53:50' , '2022-09-19 21:55:55' , inclusive='both')),['surface']] = 1
df_s.loc[(df_s['datetime'].between('2022-09-19 22:04:00' , '2022-09-19 22:06:39' , inclusive='both')),['surface']] = 1
df_s.loc[(df_s['datetime'].between('2022-09-20 20:25:50' , '2022-09-20 20:27:54' , inclusive='both')),['surface']] = 1
df_s.loc[(df_s['datetime'].between('2022-09-22 21:16:37' , '2022-09-22 21:19:56' , inclusive='both')),['surface']] = 1
df_s.loc[(df_s['datetime'].between('2022-09-22 21:43:16' , '2022-09-22 21:43:41' , inclusive='both')),['surface']] = 1

# %%
df_s['surface'].value_counts()
# Out:
# 0    6583
# 1     637
# Name: surface, dtype: int64

# %%
df_s.head()
# Out:
#    index            datetime   latitude  longitude  absoluteAltitude  \
# 0      0 2022-09-20 20:22:07  39.449977 -74.584993          0.650000
# 1      1 2022-09-20 20:22:08  39.449982 -74.584989          0.939474
# 2      2 2022-09-20 20:22:09  39.449991 -74.584983          1.602105
# 3      3 2022-09-20 20:22:10  39.450000 -74.584978          2.506389
# 4      4 2022-09-20 20:22:11  39.450010 -74.584973          2.753750
#
#    magneticHeading  trueHeading  groundSpeed  trueAirspeed     pitch  ...  \
# 0        32.175222    19.886000     1.742333      1.749539  2.787000  ...
# 1        32.293053    20.003579     2.037737      2.065586  3.426684  ...
# 2        32.466921    20.177553     2.229158      2.284727  5.960763  ...
# 3        32.672500    20.383167     2.149028      2.200058  5.446833  ...
# 4        32.770150    20.480700     2.209575      2.210113  4.934150  ...
#
#    hasWeightOnWheels  turnRate to degPerSec  cyclicPositionPitch  \
# 0                0.0              -0.344556            -7.145222
# 1                0.0              -0.249237             4.024526
# 2                0.0              -0.127316            -8.350974
# 3                0.0              -0.011861            -4.655806
# 4                0.0               0.037625            -5.008675
#
#    cyclicPositionRoll  collectivePosition  antiTorquePedalPosition  \
# 0           -1.755778           43.350556                -6.749556
# 1           -0.637526           43.419368                -6.691947
# 2            0.089816           43.846368                -6.686974
# 3           -0.398667           43.654750                -6.678250
# 4            0.533225           43.526300                -5.647800
#
#    throttlePosition   e1Torque   e2Torque  surface
# 0         53.447444  54.815889  54.815889        0
# 1         53.855500  56.059921  56.059921        0
# 2         53.765184  56.152684  56.152684        0
# 3         53.635083  55.965278  55.965278        0
# 4         53.110525  54.661125  54.661125        0
#
# [5 rows x 42 columns]

# %% [markdown]
# # Dataframe for Hover Taxi maneuver

# %%
df_h = df.copy()
df_h['hover'] = 0

df_h.loc[(df_h['datetime'].between('2022-09-19 21:57:07' , '2022-09-19 21:59:20' , inclusive='both')),['hover']] = 1
df_h.loc[(df_h['datetime'].between('2022-09-19 22:08:15' , '2022-09-19 22:10:24' , inclusive='both')),['hover']] = 1
df_h.loc[(df_h['datetime'].between('2022-09-20 20:28:44' , '2022-09-20 20:30:06' , inclusive='both')),['hover']] = 1
df_h.loc[(df_h['datetime'].between('2022-09-20 20:30:31' , '2022-09-20 20:32:16' , inclusive='both')),['hover']] = 1
df_h.loc[(df_h['datetime'].between('2022-09-20 20:32:39' , '2022-09-20 20:34:06' , inclusive='both')),['hover']] = 1
df_h.loc[(df_h['datetime'].between('2022-09-20 20:34:50' , '2022-09-20 20:36:51' , inclusive='both')),['hover']] = 1
df_h.loc[(df_h['datetime'].between('2022-09-22 21:20:41' , '2022-09-22 21:23:56' , inclusive='both')),['hover']] = 1
df_h.loc[(df_h['datetime'].between('2022-09-22 21:28:35' , '2022-09-22 21:29:46' , inclusive='both')),['hover']] = 1
df_h.loc[(df_h['datetime'].between('2022-09-22 21:44:09' , '2022-09-22 21:45:31' , inclusive='both')),['hover']] = 1

# %%
df_h['hover'].value_counts()
# Out:
# 0    6206
# 1    1014
# Name: hover, dtype: int64

# %%
df_h.head()
# Out:
#    index            datetime   latitude  longitude  absoluteAltitude  \
# 0      0 2022-09-20 20:22:07  39.449977 -74.584993          0.650000
# 1      1 2022-09-20 20:22:08  39.449982 -74.584989          0.939474
# 2      2 2022-09-20 20:22:09  39.449991 -74.584983          1.602105
# 3      3 2022-09-20 20:22:10  39.450000 -74.584978          2.506389
# 4      4 2022-09-20 20:22:11  39.450010 -74.584973          2.753750
#
#    magneticHeading  trueHeading  groundSpeed  trueAirspeed     pitch  ...  \
# 0        32.175222    19.886000     1.742333      1.749539  2.787000  ...
# 1        32.293053    20.003579     2.037737      2.065586  3.426684  ...
# 2        32.466921    20.177553     2.229158      2.284727  5.960763  ...
# 3        32.672500    20.383167     2.149028      2.200058  5.446833  ...
# 4        32.770150    20.480700     2.209575      2.210113  4.934150  ...
#
#    hasWeightOnWheels  turnRate to degPerSec  cyclicPositionPitch  \
# 0                0.0              -0.344556            -7.145222
# 1                0.0              -0.249237             4.024526
# 2                0.0              -0.127316            -8.350974
# 3                0.0              -0.011861            -4.655806
# 4                0.0               0.037625            -5.008675
#
#    cyclicPositionRoll  collectivePosition  antiTorquePedalPosition  \
# 0           -1.755778           43.350556                -6.749556
# 1           -0.637526           43.419368                -6.691947
# 2            0.089816           43.846368                -6.686974
# 3           -0.398667           43.654750                -6.678250
# 4            0.533225           43.526300                -5.647800
#
#    throttlePosition   e1Torque   e2Torque  hover
# 0         53.447444  54.815889  54.815889      0
# 1         53.855500  56.059921  56.059921      0
# 2         53.765184  56.152684  56.152684      0
# 3         53.635083  55.965278  55.965278      0
# 4         53.110525  54.661125  54.661125      0
#
# [5 rows x 42 columns]

# %% [markdown]
# #  Dataframe for Quick Stop

# %%
df_q = df.copy()
df_q['QuickStop'] = 0

df_q.loc[(df_q['datetime'].between('2022-09-19 22:00:35' , '2022-09-19 22:01:44' , inclusive='both')),['QuickStop']] = 1
df_q.loc[(df_q['datetime'].between('2022-09-19 22:11:55' , '2022-09-19 22:13:21' , inclusive='both')),['QuickStop']] = 1
df_q.loc[(df_q['datetime'].between('2022-09-22 21:36:50' , '2022-09-22 21:37:10' , inclusive='both')),['QuickStop']] = 1
df_q.loc[(df_q['datetime'].between('2022-09-22 21:39:16' , '2022-09-22 21:39:42' , inclusive='both')),['QuickStop']] = 1
df_q.loc[(df_q['datetime'].between('2022-09-22 21:40:06' , '2022-09-22 21:40:36' , inclusive='both')),['QuickStop']] = 1

# %%
df_q['QuickStop'].value_counts()
# Out:
# 0    6984
# 1     236
# Name: QuickStop, dtype: int64

# %%
df_q.head()
# Out:
#    index            datetime   latitude  longitude  absoluteAltitude  \
# 0      0 2022-09-20 20:22:07  39.449977 -74.584993          0.650000
# 1      1 2022-09-20 20:22:08  39.449982 -74.584989          0.939474
# 2      2 2022-09-20 20:22:09  39.449991 -74.584983          1.602105
# 3      3 2022-09-20 20:22:10  39.450000 -74.584978          2.506389
# 4      4 2022-09-20 20:22:11  39.450010 -74.584973          2.753750
#
#    magneticHeading  trueHeading  groundSpeed  trueAirspeed     pitch  ...  \
# 0        32.175222    19.886000     1.742333      1.749539  2.787000  ...
# 1        32.293053    20.003579     2.037737      2.065586  3.426684  ...
# 2        32.466921    20.177553     2.229158      2.284727  5.960763  ...
# 3        32.672500    20.383167     2.149028      2.200058  5.446833  ...
# 4        32.770150    20.480700     2.209575      2.210113  4.934150  ...
#
#    turnRate to degPerSec  cyclicPositionPitch  cyclicPositionRoll  \
# 0              -0.344556            -7.145222           -1.755778
# 1              -0.249237             4.024526           -0.637526
# 2              -0.127316            -8.350974            0.089816
# 3              -0.011861            -4.655806           -0.398667
# 4               0.037625            -5.008675            0.533225
#
#    collectivePosition  antiTorquePedalPosition  throttlePosition   e1Torque  \
# 0           43.350556                -6.749556         53.447444  54.815889
# 1           43.419368                -6.691947         53.855500  56.059921
# 2           43.846368                -6.686974         53.765184  56.152684
# 3           43.654750                -6.678250         53.635083  55.965278
# 4           43.526300                -5.647800         53.110525  54.661125
#
#     e2Torque  maneuver  QuickStop
# 0  54.815889       NaN          0
# 1  56.059921       NaN          0
# 2  56.152684       NaN          0
# 3  55.965278       NaN          0
# 4  54.661125       NaN          0
#
# [5 rows x 43 columns]

# %% [markdown]
# # Chose your features by doing something like this
# model_features = [ 'hasWeightOnWheels',
#             'absoluteAltitude',
#                  'magneticHeading',
#                  'groundSpeed',
#                  'climbOrDescentRate',
#                  'turnRate to degPerSec',
#                  'cyclicPositionPitch',
#                  'cyclicPositionRoll',
#                  'collectivePosition',
#                  'antiTorquePedalPosition',
#                  'throttlePosition',
#                  'e1Torque',
#                  'e2Torque']
#
# X = df[model_features]
#
# y = df['maneuver']

# %% [markdown]
# # Surface Taxi Binary Classification

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay, confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

from sklearn.utils import resample

# %%
df_s.sample?

# %%
#Edit the model features to whatever you want to include in your model
model_features = [ 'hasWeightOnWheels',
            'absoluteAltitude',
                 'magneticHeading', 
                 'groundSpeed', 
                 'climbOrDescentRate',
                 'turnRate to degPerSec',
                 'cyclicPositionPitch',
                 'cyclicPositionRoll',
                 'collectivePosition',
                 'antiTorquePedalPosition',
                 'throttlePosition',
                 'e1Torque',
                 'e2Torque']

#X is predictor features, y is classifier 
X = df_s[model_features]
y = df_s['surface']

# %%
y.value_counts()
# Out:
# 0    6583
# 1     637
# Name: surface, dtype: int64

# %%
# Separate majority and minority classes
df_majority = df_s[df_s['surface'] ==0]
df_minority = df_s[df_s['surface']==1]
 
# Downsample majority class
df_majority_downsampled = resample(df_majority, 
                                 replace=False,    # sample without replacement
                                 n_samples=637,     # to match minority class
                                 random_state=123456) # reproducible results
 
# Combine minority class with downsampled majority class
df_downsampled = pd.concat([df_majority_downsampled, df_minority])
 
# Display new class counts
df_downsampled['surface'].value_counts()
# Out:
# 0    637
# 1    637
# Name: surface, dtype: int64

# %%
#Edit the model features to whatever you want to include in your model
model_features = [ 'hasWeightOnWheels',
            'absoluteAltitude',
                 'magneticHeading', 
                 'groundSpeed', 
                 'climbOrDescentRate',
                 'turnRate to degPerSec',
                 'cyclicPositionPitch',
                 'cyclicPositionRoll',
                 'collectivePosition',
                 'antiTorquePedalPosition',
                 'throttlePosition',
                 'e1Torque',
                 'e2Torque']

#X is predictor features, y is classifier 
X = df_downsampled[model_features]
y = df_downsampled['surface']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=516516)

# %%
y_test.value_counts()
# Out:
# 1    216
# 0    205
# Name: surface, dtype: int64

# %%
linear_svc=SVC(kernel='linear', C=1) 


# fit classifier to training set
linear_svc.fit(X_train,y_train)

print('Accuracy of SVM classifier on training set: {:.2f}'
     .format(linear_svc.score(X_train, y_train)))
print('Accuracy of SVM classifier on test set: {:.4f}'
     .format(linear_svc.score(X_test, y_test)))
# Out:
# Accuracy of SVM classifier on training set: 0.95
# Accuracy of SVM classifier on test set: 0.4869

# %%
#SVC
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_test = scaler.transform(X_test)

svm = SVC()
#y_pred=svc.predict(X_test)

svm.fit(X_train, y_train)
print('Accuracy of SVM classifier on training set: {:.2f}'
     .format(svm.score(X_train, y_train)))
print('Accuracy of SVM classifier on test set: {:.4f}'
     .format(svm.score(X_test, y_test)))
# Out:
# Accuracy of SVM classifier on training set: 0.98
# Accuracy of SVM classifier on test set: 0.4869
# C:\Users\twolf\anaconda3\envs\valkyrie\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
#SVC rbf kernel and c=100
# instantiate classifier with rbf kernel and C=100
svc=SVC(C=100.0) 
svc.fit(X_train,y_train)

print('Accuracy of SVM classifier on training set: {:.4f}'
     .format(svc.score(X_train, y_train)))
print('Accuracy of SVM classifier on test set: {:.4f}'
     .format(svc.score(X_test, y_test)))
# Out:
# Accuracy of SVM classifier on training set: 0.9988
# Accuracy of SVM classifier on test set: 0.4869

# %%
poly_svc=SVC(kernel='poly', C=1.0) 


# fit classifier to training set
poly_svc.fit(X_train,y_train)


# make predictions on test set
y_pred=poly_svc.predict(X_test)


# compute and print accuracy score
print('Model accuracy score with polynomial kernel and C=1.0 : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
print('Accuracy of SVM classifier on training set: {:.2f}'
     .format(poly_svc.score(X_train, y_train)))
print('Accuracy of SVM classifier on test set: {:.4f}'
     .format(poly_svc.score(X_test, y_test)))
# Out:
# Model accuracy score with polynomial kernel and C=1.0 : 0.4869
# Accuracy of SVM classifier on training set: 0.97
# Accuracy of SVM classifier on test set: 0.4869

# %%
#NOT CLASS BALANCED

# %%
y.value_counts()
# Out:
# 0    6583
# 1     637
# Name: surface, dtype: int64

# %%
y.value_counts()/np.float(len(df_s))
# Out:
# C:\Users\twolf\AppData\Local\Temp\ipykernel_28128\1612191534.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y.value_counts()/np.float(len(df_s))
# 0    0.911773
# 1    0.088227
# Name: surface, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=516516)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7220 entries, 0 to 7219
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   hasWeightOnWheels        7220 non-null   float64
#  1   absoluteAltitude         7220 non-null   float64
#  2   magneticHeading          7220 non-null   float64
#  3   groundSpeed              7220 non-null   float64
#  4   climbOrDescentRate       7220 non-null   float64
#  5   turnRate to degPerSec    7220 non-null   float64
#  6   cyclicPositionPitch      7220 non-null   float64
#  7   cyclicPositionRoll       7220 non-null   float64
#  8   collectivePosition       7220 non-null   float64
#  9   antiTorquePedalPosition  7220 non-null   float64
#  10  throttlePosition         7220 non-null   float64
#  11  e1Torque                 7220 non-null   float64
#  12  e2Torque                 7220 non-null   float64
# dtypes: float64(13)
# memory usage: 733.4 KB

# %%
#SVC
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_test = scaler.transform(X_test)

svm = SVC()
#y_pred=svc.predict(X_test)

svm.fit(X_train, y_train)
print('Accuracy of SVM classifier on training set: {:.2f}'
     .format(svm.score(X_train, y_train)))
print('Accuracy of SVM classifier on test set: {:.4f}'
     .format(svm.score(X_test, y_test)))
# Out:
# Accuracy of SVM classifier on training set: 0.98
# Accuracy of SVM classifier on test set: 0.9148

# %%
y_test.value_counts()
# Out:
# 0    2180
# 1     203
# Name: surface, dtype: int64

# %%
null_accuracy = (2180/(2180+203))
print(null_accuracy)
# Out:
# 0.9148132605958875

# %%
#SVC rbf kernel and c=100
# instantiate classifier with rbf kernel and C=100
svc=SVC(C=100.0) 
svc.fit(X_train,y_train)

print('Accuracy of SVM classifier on training set: {:.4f}'
     .format(svc.score(X_train, y_train)))
print('Accuracy of SVM classifier on test set: {:.4f}'
     .format(svc.score(X_test, y_test)))
# Out:
# Accuracy of SVM classifier on training set: 0.9969
# Accuracy of SVM classifier on test set: 0.9148

# %%
linear_svc=SVC(kernel='linear', C=1) 


# fit classifier to training set
linear_svc.fit(X_train,y_train)
print('Accuracy of SVM classifier on training set: {:.2f}'
     .format(linear_svc.score(X_train, y_train)))
print('Accuracy of SVM classifier on test set: {:.4f}'
     .format(linear_svc.score(X_test, y_test)))

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Accuracy of SVM classifier on training set: 0.96
# Accuracy of SVM classifier on test set: 0.9148
# [[1754  426]
#  [  19  184]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.80      0.89      2180
#            1       0.30      0.91      0.45       203
#
#     accuracy                           0.81      2383
#    macro avg       0.65      0.86      0.67      2383
# weighted avg       0.93      0.81      0.85      2383

# %%
from sklearn.pipeline import Pipeline

# %%
Pipeline?

# %%
poly_svc=SVC(kernel='poly', C=1.0) 


# fit classifier to training set
poly_svc.fit(X_train,y_train)


# make predictions on test set
y_pred=poly_svc.predict(X_test)


# compute and print accuracy score
print('Model accuracy score with polynomial kernel and C=1.0 : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
print('Accuracy of SVM classifier on training set: {:.2f}'
     .format(poly_svc.score(X_train, y_train)))
print('Accuracy of SVM classifier on test set: {:.4f}'
     .format(poly_svc.score(X_test, y_test)))
# Out:
# Model accuracy score with polynomial kernel and C=1.0 : 0.7503
# Accuracy of SVM classifier on training set: 0.98
# Accuracy of SVM classifier on test set: 0.7503

# %%
# instantiate classifier with sigmoid kernel and C=100.0
sigmoid_svc100=SVC(kernel='sigmoid', C=1.0) 


# fit classifier to training set
sigmoid_svc100.fit(X_train,y_train)


# make predictions on test set
y_pred=sigmoid_svc100.predict(X_test)


# compute and print accuracy score
print('Model accuracy score with sigmoid kernel and C=100.0 : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with sigmoid kernel and C=100.0 : 0.8133
