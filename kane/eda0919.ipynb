# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
#from IPython.display import display, HTML
#display(HTML("<style>.container { width:100% !important; }</style>"))

# %%
pd.set_option('display.max_columns', None)

# %%
# Create a custom function for data transformation
features = ['datetime',
            'latitude',
            'longitude',
            'absoluteAltitude',
            'magneticHeading',
            'trueHeading',
            'groundSpeed',
            'trueAirspeed',
            'pitch',
            'roll',
            'yaw',
            'angleOfAttack',
            'flightPathAngle',
            'verticalFlightPathAngle',
            'horizontalFlightPathAngle',
            'rollAcceleration',
            'pitchAcceleration',
            'yawAcceleration',
            'e1N1ng',
            'e2N1ng',
            'e1N2nf',
            'e2N2nf',
            'mainRotorRpm',
            'tailRotorRpm',
            'mainRotorTorque',
            'e1Itt',
            'e2Itt',
            'mainRotorInducedInflow',
            'flightDirectorPitch',
            'flightDirectorRoll',
            'climbOrDescentRate',
            'hasWeightOnWheels',
            'turnRate to degPerSec',
            'cyclicPositionPitch',
            'cyclicPositionRoll',
            'collectivePosition',
            'antiTorquePedalPosition',
            'throttlePosition',
            'e1Torque',
            'e2Torque'
]

def df_transformation(df):
    df_temp = df[features]
    df_temp['datetime'] = df_temp.datetime.dt.strftime('%Y-%m-%d %H:%M:%S').astype('datetime64[ns]')

    output = df_temp.groupby(by=["datetime"], dropna=False).mean().reset_index()
    
    return output

# %%
# reading files from 9/19 dataset
df1 = pd.read_csv('SimData_2022.09.19_16.00.36.csv.roar.csv',
                parse_dates = {'datetime': ['date', 'time']},
                low_memory=False)
df1 = df_transformation(df1)
# Out:
# C:\Users\kanev\AppData\Local\Temp\ipykernel_5080\1488056606.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['datetime'] = df_temp.datetime.dt.strftime('%Y-%m-%d %H:%M:%S').astype('datetime64[ns]')

# %%
df2 = pd.read_csv('SimData_2022.09.19_16.38.20.csv.roar.csv',
                parse_dates = {'datetime': ['date', 'time']},
                low_memory=False)
df2 = df_transformation(df2)
# Out:
# C:\Users\kanev\AppData\Local\Temp\ipykernel_5080\950947015.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['datetime'] = df_temp.datetime.dt.strftime('%Y-%m-%d %H:%M:%S').astype('datetime64[ns]')

# %%
df3 = pd.read_csv('SimData_2022.09.19_17.51.37.csv.roar.csv',
                parse_dates = {'datetime': ['date', 'time']},
                low_memory=False)
df3 = df_transformation(df3)
# Out:
# C:\Users\kanev\AppData\Local\Temp\ipykernel_5080\950947015.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['datetime'] = df_temp.datetime.dt.strftime('%Y-%m-%d %H:%M:%S').astype('datetime64[ns]')

# %%
len(df1)+len(df2)+len(df3)
# Out:
# 3952

# %%
df = pd.concat([df1,df2,df3]).reset_index()
len(df)
# Out:
# 3952

# %%
df
# Out:
#       index            datetime   latitude  longitude  absoluteAltitude  \
# 0         0 2022-09-19 20:01:09  39.358996 -74.434692          0.032500
# 1         1 2022-09-19 20:01:10  39.358996 -74.434692          0.054773
# 2         2 2022-09-19 20:01:11  39.358996 -74.434692          0.060000
# 3         3 2022-09-19 20:01:12  39.358996 -74.434692          0.060000
# 4         4 2022-09-19 20:01:13  39.358996 -74.434692          0.060000
# ...     ...                 ...        ...        ...               ...
# 3947   1312 2022-09-19 22:13:39  39.880639 -75.226289          0.130000
# 3948   1313 2022-09-19 22:13:40  39.880639 -75.226289          0.131200
# 3949   1314 2022-09-19 22:13:41  39.880639 -75.226289          0.138750
# 3950   1315 2022-09-19 22:13:42  39.880639 -75.226289          0.130000
# 3951   1316 2022-09-19 22:13:43  39.880639 -75.226289          0.130000
#
#       magneticHeading  trueHeading  groundSpeed  trueAirspeed     pitch  \
# 0          343.437625   331.099250     0.137500      0.205666  0.219875
# 1          341.506909   329.168455     0.155500      0.170178 -0.247591
# 2          341.011659   328.673114     0.018477      0.019431 -0.172818
# 3          341.334978   328.996422     0.005200      0.005306 -0.167422
# 4          341.558604   329.220042     0.002542      0.002629 -0.172063
# ...               ...          ...          ...           ...       ...
# 3947       358.731000   346.676000     0.000000      0.000000  1.045620
# 3948       358.688300   346.633300     0.012440      0.012490  1.048880
# 3949       358.165396   346.110333     0.017917      0.018836  1.068812
# 3950       358.165184   346.110184     0.009347      0.009951  0.917449
# 3951       358.313667   346.258556     0.003444      0.003643  0.910667
#
#           roll         yaw  angleOfAttack  flightPathAngle  \
# 0     0.278250  331.373625       1.574125              0.0
# 1     0.044932  329.445955      -1.753000              0.0
# 2    -0.102977  328.950159       0.529659              0.0
# 3    -0.149267  329.273400       0.004778              0.0
# 4    -0.150312  329.497063       0.043229              0.0
# ...        ...         ...            ...              ...
# 3947  0.078000  346.818920      -0.006440              0.0
# 3948  0.072880  346.776140      -0.927940              0.0
# 3949  0.063062  346.253146      -0.708375              0.0
# 3950  0.059041  346.253143       0.035878              0.0
# 3951  0.049296  346.401556      -0.026222              0.0
#
#       verticalFlightPathAngle  horizontalFlightPathAngle  rollAcceleration  \
# 0                    0.257875                 331.099250         -4.041994
# 1                   -0.197500                 329.168455          0.493045
# 2                   -0.119591                 328.673114          0.017623
# 3                   -0.116156                 328.996422          0.002307
# 4                   -0.122250                 329.220042          0.001535
# ...                       ...                        ...               ...
# 3947                 1.455840                 346.676000          0.000020
# 3948                 1.459340                 346.633300          0.000923
# 3949                 1.480021                 346.110333         -0.004292
# 3950                 1.328735                 346.110184          0.000358
# 3951                 1.321630                 346.258556          0.001583
#
#       pitchAcceleration  yawAcceleration     e1N1ng     e2N1ng      e1N2nf  \
# 0             -1.269124        -0.730988  51.436875  51.436875   98.242750
# 1              0.525428         0.610265  58.727477  58.727477   92.516341
# 2             -0.004922         0.055029  70.974841  70.974841   91.225750
# 3             -0.005156        -0.010993  81.245956  81.245956   91.185044
# 4              0.001055        -0.024445  88.309938  88.309938   92.883333
# ...                 ...              ...        ...        ...         ...
# 3947          -0.000311         0.000002  80.164000  80.164000  100.000000
# 3948           0.011827        -0.090184  77.373980  77.373980   99.791360
# 3949          -0.039495         0.100812  58.680604  58.680604   94.733167
# 3950           0.026639         0.006430  55.520184  55.520184   86.451694
# 3951          -0.002491        -0.011526  55.248481  55.248481   81.291481
#
#           e2N2nf  mainRotorRpm  tailRotorRpm  mainRotorTorque       e1Itt  \
# 0      98.242750      0.606367      3.368717       -21.172125   68.890875
# 1      92.516341      0.588720      3.270668       -19.832068  296.786568
# 2      91.225750      0.565812      3.143395        -8.129818  492.122841
# 3      91.185044      0.557039      3.094659        23.278067  548.774533
# 4      92.883333      0.567882      3.154911        53.377396  572.406104
# ...          ...           ...           ...              ...         ...
# 3947  100.000000      0.610867      3.393700        26.617260  537.835480
# 3948   99.791360      0.609364      3.385353        12.847320  525.879140
# 3949   94.733167      0.590836      3.282424       -13.985958  493.885000
# 3950   86.451694      0.569382      3.163231       -10.407633  551.827143
# 3951   81.291481      0.554730      3.081825        -8.222074  580.424148
#
#            e2Itt  mainRotorInducedInflow  flightDirectorPitch  \
# 0      68.890875              -26.476875             0.290625
# 1     296.786568              -33.095409            -0.196682
# 2     492.122841              -27.582932            -0.119955
# 3     548.774533              -25.925644            -0.116222
# 4     572.406104              -26.168917            -0.122229
# ...          ...                     ...                  ...
# 3947  537.835480              -28.515000             1.455000
# 3948  525.879140              -28.486960             1.455000
# 3949  493.885000              -27.725479             1.455000
# 3950  551.827143              -26.581408             1.455000
# 3951  580.424148              -25.814889             1.455000
#
#       flightDirectorRoll  climbOrDescentRate  hasWeightOnWheels  \
# 0               0.635875            0.582125           1.000000
# 1               0.406386            2.061705           1.000000
# 2               0.258500            1.114295           1.000000
# 3               0.211444            0.181933           1.000000
# 4               0.210375           -0.000208           1.000000
# ...                  ...                 ...                ...
# 3947            0.164000            0.003080           0.000000
# 3948            0.164000            0.005680           0.000000
# 3949            0.164000            0.134792           0.000000
# 3950            0.164000           -0.220551           0.877551
# 3951            0.164000           -0.135593           1.000000
#
#       turnRate to degPerSec  cyclicPositionPitch  cyclicPositionRoll  \
# 0                 -0.195750            24.912250           -4.404250
# 1                 -0.824295             0.949909            1.013386
# 2                 -0.669841            -0.176841            0.624068
# 3                 -0.309289             0.039356            0.124244
# 4                 -0.118042             0.065479            0.052958
# ...                     ...                  ...                 ...
# 3947               0.000000            35.880560           -0.327840
# 3948              -0.015900            35.667180           -0.170200
# 3949              -0.173458            35.856792           -0.273375
# 3950              -0.099469            38.219143           -0.044633
# 3951              -0.020333            39.299963            0.045037
#
#       collectivePosition  antiTorquePedalPosition  throttlePosition  \
# 0               3.726000               -38.213000          7.283500
# 1               3.726000               -38.213000         39.997136
# 2               3.726000               -38.216068         87.756318
# 3               3.726000               -38.228200        100.000000
# 4               3.726000               -38.282792        100.000000
# ...                  ...                      ...               ...
# 3947            3.760000               -25.606000         46.294000
# 3948            3.759300               -25.606000         26.850520
# 3949            3.757000               -25.606000          0.000000
# 3950            3.754796               -25.223796          0.000000
# 3951            3.754000               -25.056333          0.000000
#
#        e1Torque   e2Torque  Surface_Taxi  Hover_Taxi  Quick_Stop
# 0     -5.219500  -5.219500           NaN         NaN         NaN
# 1     -3.727205  -3.727205           NaN         NaN         NaN
# 2      6.978659   6.978659           NaN         NaN         NaN
# 3     28.398222  28.398222           NaN         NaN         NaN
# 4     56.248208  56.248208           NaN         NaN         NaN
# ...         ...        ...           ...         ...         ...
# 3947  39.719760  39.719760           0.0         0.0         0.0
# 3948  30.480700  30.480700           0.0         0.0         0.0
# 3949  -3.314687  -3.314687           0.0         0.0         0.0
# 3950  -3.275878  -3.275878           0.0         0.0         0.0
# 3951  -2.217222  -2.217222           0.0         0.0         0.0
#
# [3952 rows x 44 columns]

# %%
#normalize values for entire dataframe
df_norm = df.loc[:, df.columns != 'datetime']
df_norm = (df_norm-df_norm.min())/(df_norm.max()-df_norm.min())
df_norm.insert(1, 'datetime', df[['datetime']])

# %%
df_norm
# Out:
#          index            datetime  latitude  longitude  absoluteAltitude  \
# 0     0.000000 2022-09-19 20:01:09  0.052203   0.806706          0.000000
# 1     0.000739 2022-09-19 20:01:10  0.052203   0.806706          0.000008
# 2     0.001477 2022-09-19 20:01:11  0.052203   0.806706          0.000010
# 3     0.002216 2022-09-19 20:01:12  0.052203   0.806706          0.000010
# 4     0.002954 2022-09-19 20:01:13  0.052203   0.806706          0.000010
# ...        ...                 ...       ...        ...               ...
# 3947  0.968981 2022-09-19 22:13:39  0.999996   0.029835          0.000035
# 3948  0.969719 2022-09-19 22:13:40  0.999996   0.029835          0.000035
# 3949  0.970458 2022-09-19 22:13:41  0.999996   0.029835          0.000038
# 3950  0.971196 2022-09-19 22:13:42  0.999996   0.029835          0.000035
# 3951  0.971935 2022-09-19 22:13:43  0.999996   0.029835          0.000035
#
#       magneticHeading  trueHeading  groundSpeed  trueAirspeed     pitch  \
# 0            0.955115     0.920651     0.000932      0.001393  0.523824
# 1            0.949742     0.915275     0.001054      0.001153  0.509269
# 2            0.948363     0.913896     0.000125      0.000132  0.511597
# 3            0.949263     0.914796     0.000035      0.000036  0.511765
# 4            0.949886     0.915419     0.000017      0.000018  0.511621
# ...               ...          ...          ...           ...       ...
# 3947         0.997674     0.964025     0.000000      0.000000  0.549535
# 3948         0.997555     0.963906     0.000084      0.000085  0.549636
# 3949         0.996100     0.962450     0.000121      0.000128  0.550257
# 3950         0.996099     0.962450     0.000063      0.000067  0.545544
# 3951         0.996512     0.962863     0.000023      0.000025  0.545333
#
#           roll       yaw  angleOfAttack  flightPathAngle  \
# 0     0.380356  0.921854       0.496897              NaN
# 1     0.377179  0.916485       0.487459              NaN
# 2     0.375165  0.915104       0.493934              NaN
# 3     0.374535  0.916005       0.492445              NaN
# 4     0.374521  0.916627       0.492554              NaN
# ...        ...       ...            ...              ...
# 3947  0.377629  0.964870       0.492413              NaN
# 3948  0.377559  0.964751       0.489799              NaN
# 3949  0.377426  0.963294       0.490422              NaN
# 3950  0.377371  0.963294       0.492534              NaN
# 3951  0.377238  0.963708       0.492357              NaN
#
#       verticalFlightPathAngle  horizontalFlightPathAngle  rollAcceleration  \
# 0                    0.505227                   0.922804          0.000000
# 1                    0.500234                   0.917409          0.848592
# 2                    0.501088                   0.916024          0.759632
# 3                    0.501126                   0.916928          0.756766
# 4                    0.501059                   0.917553          0.756621
# ...                       ...                        ...               ...
# 3947                 0.518364                   0.966333          0.756338
# 3948                 0.518403                   0.966213          0.756507
# 3949                 0.518630                   0.964752          0.755531
# 3950                 0.516971                   0.964752          0.756401
# 3951                 0.516893                   0.965166          0.756630
#
#       pitchAcceleration  yawAcceleration    e1N1ng    e2N1ng    e1N2nf  \
# 0              0.345915         0.144051  0.012571  0.012571  0.923485
# 1              0.972046         1.000000  0.188188  0.188188  0.837899
# 2              0.787003         0.645664  0.483205  0.483205  0.818610
# 3              0.786922         0.603531  0.730617  0.730617  0.818002
# 4              0.789089         0.594946  0.900775  0.900775  0.843384
# ...                 ...              ...       ...       ...       ...
# 3947           0.788612         0.610548  0.704554  0.704554  0.949749
# 3948           0.792847         0.552993  0.637348  0.637348  0.946630
# 3949           0.774940         0.674882  0.187059  0.187059  0.871032
# 3950           0.798015         0.614650  0.110930  0.110930  0.747258
# 3951           0.787851         0.603191  0.104386  0.104386  0.670134
#
#         e2N2nf  mainRotorRpm  tailRotorRpm  mainRotorTorque     e1Itt  \
# 0     0.923485      0.938695      0.938699         0.000000  0.033177
# 1     0.837899      0.895522      0.895520         0.010696  0.437470
# 2     0.818610      0.839477      0.839471         0.104097  0.784002
# 3     0.818002      0.818011      0.818009         0.354777  0.884504
# 4     0.843384      0.844540      0.844543         0.595014  0.926427
# ...        ...           ...           ...              ...       ...
# 3947  0.949749      0.949705      0.949701         0.381429  0.865098
# 3948  0.946630      0.946027      0.946025         0.271525  0.843887
# 3949  0.871032      0.900699      0.900697         0.057356  0.787128
# 3950  0.747258      0.848210      0.848207         0.085916  0.889919
# 3951  0.670134      0.812362      0.812357         0.103360  0.940651
#
#          e2Itt  mainRotorInducedInflow  flightDirectorPitch  \
# 0     0.033177                0.085007             0.516807
# 1     0.437470                0.001926             0.501657
# 2     0.784002                0.071123             0.504043
# 3     0.884504                0.091927             0.504159
# 4     0.926427                0.088873             0.503972
# ...        ...                     ...                  ...
# 3947  0.865098                0.059423             0.553005
# 3948  0.843887                0.059775             0.553005
# 3949  0.787128                0.069334             0.553005
# 3950  0.889919                0.083695             0.553005
# 3951  0.940651                0.093317             0.553005
#
#       flightDirectorRoll  climbOrDescentRate  hasWeightOnWheels  \
# 0               0.424373            0.533758           1.000000
# 1               0.420132            0.534132           1.000000
# 2               0.417399            0.533893           1.000000
# 3               0.416530            0.533657           1.000000
# 4               0.416510            0.533611           1.000000
# ...                  ...                 ...                ...
# 3947            0.415653            0.533612           0.000000
# 3948            0.415653            0.533613           0.000000
# 3949            0.415653            0.533646           0.000000
# 3950            0.415653            0.533556           0.877551
# 3951            0.415653            0.533577           1.000000
#
#       turnRate to degPerSec  cyclicPositionPitch  cyclicPositionRoll  \
# 0                  0.467375             0.841337            0.318690
# 1                  0.362617             0.691023            0.395066
# 2                  0.388360             0.683955            0.389577
# 3                  0.448452             0.685311            0.382531
# 4                  0.480326             0.685475            0.381526
# ...                     ...                  ...                 ...
# 3947               0.500000             0.910140            0.376158
# 3948               0.497350             0.908802            0.378380
# 3949               0.471090             0.909991            0.376925
# 3950               0.483422             0.924810            0.380150
# 3951               0.496611             0.931590            0.381414
#
#       collectivePosition  antiTorquePedalPosition  throttlePosition  e1Torque  \
# 0               0.005988                 0.256808          0.072835  0.001887
# 1               0.005988                 0.256808          0.399971  0.014923
# 2               0.005988                 0.256786          0.877563  0.108446
# 3               0.005988                 0.256698          1.000000  0.295559
# 4               0.005988                 0.256301          1.000000  0.538845
# ...                  ...                      ...               ...       ...
# 3947            0.006664                 0.348437          0.462940  0.394459
# 3948            0.006650                 0.348437          0.268505  0.313750
# 3949            0.006605                 0.348437          0.000000  0.018527
# 3950            0.006561                 0.351215          0.000000  0.018866
# 3951            0.006545                 0.352432          0.000000  0.028114
#
#       e2Torque  Surface_Taxi  Hover_Taxi  Quick_Stop
# 0     0.001887           NaN         NaN         NaN
# 1     0.014923           NaN         NaN         NaN
# 2     0.108446           NaN         NaN         NaN
# 3     0.295559           NaN         NaN         NaN
# 4     0.538845           NaN         NaN         NaN
# ...        ...           ...         ...         ...
# 3947  0.394459           NaN         NaN         NaN
# 3948  0.313750           NaN         NaN         NaN
# 3949  0.018527           NaN         NaN         NaN
# 3950  0.018866           NaN         NaN         NaN
# 3951  0.028114           NaN         NaN         NaN
#
# [3952 rows x 44 columns]

# %%
#normalize values only for dataframe with flight logs
df3_norm = df3.loc[:, df3.columns != 'datetime']
df3_norm = (df3_norm-df3_norm.min())/(df3_norm.max()-df3_norm.min())
df3_norm.insert(1, 'datetime', df3[['datetime']])

# %%
df3_norm
# Out:
#       latitude            datetime  longitude  absoluteAltitude  \
# 0     0.592929 2022-09-19 21:51:47   0.717743          0.000503
# 1     0.592929 2022-09-19 21:51:48   0.717772          0.000965
# 2     0.592929 2022-09-19 21:51:49   0.717808          0.001277
# 3     0.592929 2022-09-19 21:51:50   0.717809          0.001296
# 4     0.592929 2022-09-19 21:51:51   0.717809          0.001180
# ...        ...                 ...        ...               ...
# 1312  0.999896 2022-09-19 22:13:39   0.995907          0.000359
# 1313  0.999896 2022-09-19 22:13:40   0.995907          0.000365
# 1314  0.999896 2022-09-19 22:13:41   0.995907          0.000399
# 1315  0.999896 2022-09-19 22:13:42   0.995907          0.000359
# 1316  0.999896 2022-09-19 22:13:43   0.995907          0.000359
#
#       magneticHeading  trueHeading  groundSpeed  trueAirspeed     pitch  \
# 0            0.750913     0.717289     0.001564      0.001914  0.585274
# 1            0.748780     0.715156     0.003028      0.003295  0.640383
# 2            0.745007     0.711382     0.001728      0.001749  0.680533
# 3            0.741227     0.707602     0.000939      0.000962  0.682639
# 4            0.741423     0.707799     0.001992      0.002040  0.666696
# ...               ...          ...          ...           ...       ...
# 1312         0.997809     0.964178     0.000000      0.000000  0.549535
# 1313         0.997690     0.964059     0.000206      0.000206  0.549636
# 1314         0.996234     0.962603     0.000296      0.000311  0.550257
# 1315         0.996233     0.962602     0.000154      0.000164  0.545544
# 1316         0.996646     0.963015     0.000057      0.000060  0.545333
#
#           roll       yaw  angleOfAttack  flightPathAngle  \
# 0     0.357506  0.718435       0.305518              NaN
# 1     0.371336  0.716335       0.269358              NaN
# 2     0.373902  0.712586       0.294326              NaN
# 3     0.373640  0.708805       0.325951              NaN
# 4     0.375545  0.708992       0.332351              NaN
# ...        ...       ...            ...              ...
# 1312  0.332846  0.965408       0.328357              NaN
# 1313  0.332519  0.965289       0.324898              NaN
# 1314  0.331890  0.963831       0.325722              NaN
# 1315  0.331633  0.963831       0.328516              NaN
# 1316  0.331010  0.964245       0.328283              NaN
#
#       verticalFlightPathAngle  horizontalFlightPathAngle  rollAcceleration  \
# 0                    0.527550                   0.718669          0.451654
# 1                    0.546900                   0.716529          0.387104
# 2                    0.560937                   0.712742          0.398662
# 3                    0.561573                   0.708949          0.392159
# 4                    0.555964                   0.709146          0.378760
# ...                       ...                        ...               ...
# 1312                 0.518364                   0.966424          0.398335
# 1313                 0.518403                   0.966305          0.398961
# 1314                 0.518630                   0.964843          0.395346
# 1315                 0.516971                   0.964843          0.398569
# 1316                 0.516893                   0.965257          0.399419
#
#       pitchAcceleration  yawAcceleration    e1N1ng    e2N1ng    e1N2nf  \
# 0              1.000000         0.448114  0.450936  0.450936  0.831224
# 1              0.337539         0.601600  0.083374  0.083374  0.598500
# 2              0.383575         0.619367  0.147881  0.147881  0.268643
# 3              0.426900         0.722994  0.451987  0.451987  0.354651
# 4              0.440365         0.838774  0.716066  0.716066  0.423228
# ...                 ...              ...       ...       ...       ...
# 1312           0.473234         0.620278  0.678385  0.678385  0.863338
# 1313           0.483787         0.557197  0.602420  0.602420  0.853710
# 1314           0.439165         0.690789  0.093448  0.093448  0.620291
# 1315           0.496666         0.624774  0.007398  0.007398  0.238127
# 1316           0.471338         0.612215  0.000000  0.000000  0.000000
#
#         e2N2nf  mainRotorRpm  tailRotorRpm  mainRotorTorque     e1Itt  \
# 0     0.831224      0.697675      0.697669         0.109852  0.105591
# 1     0.598500      0.491138      0.491122         0.044180  0.042849
# 2     0.268643      0.233377      0.233358         0.077697  0.665423
# 3     0.354651      0.023527      0.023523         0.188124  0.839710
# 4     0.423228      0.000000      0.000000         0.534987  0.747488
# ...        ...           ...           ...              ...       ...
# 1312  0.863338      0.761762      0.761737         0.454313  0.421577
# 1313  0.853710      0.742034      0.742016         0.300240  0.306890
# 1314  0.620291      0.498850      0.498836         0.000000  0.000000
# 1315  0.238127      0.217247      0.217229         0.040038  0.555786
# 1316  0.000000      0.024918      0.024901         0.064493  0.830091
#
#          e2Itt  mainRotorInducedInflow  flightDirectorPitch  \
# 0     0.105591                0.002582             0.572528
# 1     0.042849                0.015875             0.572528
# 2     0.665423                0.035540             0.572528
# 3     0.839710                0.048793             0.572528
# 4     0.747488                0.053482             0.572528
# ...        ...                     ...                  ...
# 1312  0.421577                0.014269             0.553005
# 1313  0.306890                0.014644             0.553005
# 1314  0.000000                0.024829             0.553005
# 1315  0.555786                0.040132             0.553005
# 1316  0.830091                0.050384             0.553005
#
#       flightDirectorRoll  climbOrDescentRate  hasWeightOnWheels  \
# 0               0.319261            0.544984           0.000000
# 1               0.319261            0.548226           0.000000
# 2               0.319261            0.549050           0.000000
# 3               0.319261            0.546429           0.000000
# 4               0.319261            0.544420           0.000000
# ...                  ...                 ...                ...
# 1312            0.346126            0.544907           0.000000
# 1313            0.346126            0.544909           0.000000
# 1314            0.346126            0.545021           0.000000
# 1315            0.346126            0.544713           0.877551
# 1316            0.346126            0.544786           1.000000
#
#       turnRate to degPerSec  cyclicPositionPitch  cyclicPositionRoll  \
# 0                  0.502643             1.000000            0.951415
# 1                  0.467990             0.868280            1.000000
# 2                  0.415224             0.883811            0.983253
# 3                  0.383299             0.878862            0.968395
# 4                  0.437401             0.882082            0.966003
# ...                     ...                  ...                 ...
# 1312               0.500000             0.910140            0.485092
# 1313               0.497350             0.908802            0.487958
# 1314               0.471090             0.909991            0.486082
# 1315               0.483422             0.924810            0.490241
# 1316               0.496611             0.931590            0.491871
#
#       collectivePosition  antiTorquePedalPosition  throttlePosition  e1Torque  \
# 0               0.004292                 0.903874          0.000000  0.212666
# 1               0.004269                 0.903816          0.010279  0.000000
# 2               0.004342                 0.903747          0.472123  0.028687
# 3               0.004467                 0.903702          0.971614  0.155388
# 4               0.004510                 0.903671          1.000000  0.406942
# ...                  ...                      ...               ...       ...
# 1312            0.007113                 0.487168          0.462940  0.527441
# 1313            0.007098                 0.487168          0.268505  0.414791
# 1314            0.007049                 0.487168          0.000000  0.002728
# 1315            0.007001                 0.491052          0.000000  0.003202
# 1316            0.006984                 0.492754          0.000000  0.016110
#
#       e2Torque  Surface_Taxi  Hover_Taxi  Quick_Stop
# 0     0.212666           0.0         0.0         0.0
# 1     0.000000           0.0         0.0         0.0
# 2     0.028687           0.0         0.0         0.0
# 3     0.155388           0.0         0.0         0.0
# 4     0.406942           0.0         0.0         0.0
# ...        ...           ...         ...         ...
# 1312  0.527441           0.0         0.0         0.0
# 1313  0.414791           0.0         0.0         0.0
# 1314  0.002728           0.0         0.0         0.0
# 1315  0.003202           0.0         0.0         0.0
# 1316  0.016110           0.0         0.0         0.0
#
# [1317 rows x 43 columns]

# %%
#Add columns for surface and hover taxi maneuvers and default set value to zero
df['Surface_Taxi'] = 0
df['Hover_Taxi'] = 0
df['Quick_Stop'] = 0

# %%
#Add columns for surface and hover taxi maneuvers and default set value to zero
df_norm['Surface_Taxi'] = 0
df_norm['Hover_Taxi'] = 0
df_norm['Quick_Stop'] = 0

# %%
#label data points
df.loc[(df['datetime'].between('2022-09-19 21:53:50' , '2022-09-19 21:55:55' , inclusive='both')),['Surface_Taxi']] = 20
df.loc[(df['datetime'].between('2022-09-19 21:57:07' , '2022-09-19 21:59:20' , inclusive='both')),['Hover_Taxi']] = 40
df.loc[(df['datetime'].between('2022-09-19 22:00:35' , '2022-09-19 22:01:44' , inclusive='both')),['Quick_Stop']] = 80
df.loc[(df['datetime'].between('2022-09-19 22:04:00' , '2022-09-19 22:06:39' , inclusive='both')),['Surface_Taxi']] = 20
df.loc[(df['datetime'].between('2022-09-19 22:08:15' , '2022-09-19 22:10:24' , inclusive='both')),['Hover_Taxi']] = 40
df.loc[(df['datetime'].between('2022-09-19 22:11:55' , '2022-09-19 22:13:21' , inclusive='both')),['Quick_Stop']] = 80

# %%
#label data points
df_norm.loc[(df_norm['datetime'].between('2022-09-19 21:53:50' , '2022-09-19 21:55:55' , inclusive='both')),['Surface_Taxi']] = 1
df_norm.loc[(df_norm['datetime'].between('2022-09-19 21:57:07' , '2022-09-19 21:59:20' , inclusive='both')),['Hover_Taxi']] = 1
df_norm.loc[(df_norm['datetime'].between('2022-09-19 22:00:35' , '2022-09-19 22:01:44' , inclusive='both')),['Quick_Stop']] = 1
df_norm.loc[(df_norm['datetime'].between('2022-09-19 22:04:00' , '2022-09-19 22:06:39' , inclusive='both')),['Surface_Taxi']] = 1
df_norm.loc[(df_norm['datetime'].between('2022-09-19 22:08:15' , '2022-09-19 22:10:24' , inclusive='both')),['Hover_Taxi']] = 1
df_norm.loc[(df_norm['datetime'].between('2022-09-19 22:11:55' , '2022-09-19 22:13:21' , inclusive='both')),['Quick_Stop']] = 1

# %%
#correlation heatmap
df_corr = df.corr()
plt.figure(figsize=(16, 10))
cmap = sns.diverging_palette(150, 260, as_cmap=True)
mask = np.triu(np.ones_like(df_corr, dtype=bool))
sns.heatmap(df_corr, mask=mask, cmap=cmap).set(title = 'Correlation Heatmap')
# Out:
# [Text(0.5, 1.0, 'Correlation Heatmap')]

# %%
#Plot Ground Speed vs altitude over time - during period with flight logs
df_groundspd_alt = df.loc[(df['datetime'].between('2022-09-19 21:50:45' , '2022-09-19 22:25:25', inclusive='both')),['datetime', 'groundSpeed', 'absoluteAltitude', 'Surface_Taxi', 'Hover_Taxi', 'Quick_Stop']]
plt.figure(figsize=(16, 10))
p = sns.lineplot(data = df_groundspd_alt).set(title = 'Identifying Maneuvers Using Ground Speed and Altitude', xlabel = 'Time')

# %%
#Plot Ground Speed vs altitude over time
df_wheels = df_norm.loc[(df_norm['datetime'].between('2022-09-19 21:50:45' , '2022-09-19 22:25:25' , inclusive='both')),['datetime', 'climbOrDescentRate', 'Surface_Taxi', 'Hover_Taxi', 'Quick_Stop']]
plt.figure(figsize=(16, 10))
p = sns.lineplot(data = df_wheels).set(title = 'Identifying Maneuvers Using Weight On Wheels', xlabel = 'time')
